# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/raw/store_data.csv")
# df.columns
df[["Customer ID", "Customer Name", "City", "State", "Postal Code", "Country", "Region"]]
# les données à caractère personnel présentes dans le dataset.

# %%
# import os
# import hashlib
# from dotenv import load_dotenv

# load_dotenv()
# salt_cle = os.getenv("SECRET_SALT").encode("utf-8")

# def pseudonymize(value, secret):
#     if pd.isna(value):
#         return "Inconnue"
#     normalized_donne = str(value).strip().lower().encode("utf-8")
#     hasher = hashlib.sha256()
#     hasher.update(normalized_donne+secret)
#     return hasher.hexdigest()

# df[["Customer ID", "Customer Name", "City", "State", "Postal Code", "Country", "Region"]] = df[["Customer ID", "Customer Name", "City", "State", "Postal Code", "Country", "Region"]].apply(lambda x: pseudonymize(x, salt_cle))
# df_final = df.drop(columns=["Customer ID", "Customer Name", "City", "State", "Postal Code", "Country", "Region"])
# df_final.to_csv("donnees_pseudonymisees.csv", index=False)
